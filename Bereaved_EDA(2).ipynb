# %% [markdown]
# # Exploring 360 Giving data on bereavement related services

# %% [markdown]
# This workbook sets out the data preperation steps as well as analysis on the UK data.
#
# Step 1: Data preparation of the GrantNav data
#
# Step 2: Prep and understand the data relating to when data from funders started being part of the GrantNav database.
#
# Step 3: Merge the two datasets into one large dataset
#
# Step 4: Reduce it to a 3 Financial Year dataset and ensure we have a consistent time series (following analysis in Step 3)
#
# Step 5: How much grant funding is awarded to Bereavement Services overall in these 3 FY?
#
# Step 6: Descriptive stats on the entire dataset and split by Financial Year

# %%
#Import packages for analysis
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sn
import datetime as dt

# %%
#Presenting non trunctated output
#Set presentation options
pd.options.display.max_columns = 250 # to avoid truncated output 
pd.options.display.max_rows = 1450 #
pd.options.display.max_colwidth = 250 # avoid truncating cell content

# %%
### Read in data
#1)The merged data file from a number of GrantNav searches
UK_data = pd.read_csv('C:/Users/sonja/Desktop/Life_Admin/Bereavement_Services/data_5yrs.csv')
#2) Data file from 360 Giving that helps us work out from which point
Joiners_360 = pd.read_csv('C:/Users/sonja/Desktop/Life_Admin/Bereavement_Services/360Giving publisher_first_publish_award_dates.csv')

# %%
UK_data.shape
# Out:
# (1139, 79)

# %%
Joiners_360.shape
# Out:
# (146, 6)

# %% [markdown]
# ### Step 1 : Data preparation of the GrantNav data

# %% [markdown]
# This section:
#  - drops columns from the UK_data dataframe that are all nulls as well as other cols that are not relevant to this analysis;
#  - changes to the column headers, specifically to remove symbols that affect how python reads the string;
#  - adds two columns to the UK_data dataframe - one for financial year and secondly a country column so we can more easily group recipients by UK nation in case we want to

# %%
#Drop any cols where all variables are null
UK_data = UK_data.dropna(axis = 1, how = 'all') #axis 1 relates to cols
UK_data.shape
# Out:
# (1139, 56)

# %%
Joiners_360 = Joiners_360.dropna(axis = 1, how = 'all')
Joiners_360.shape
# Out:
# (146, 6)

# %% [markdown]
# We now have 56 columns for GrantNav UK_data, down from 79. And we have 6 cols for the 360 dataset showing which funders  started submitting data to the database when. We're going to tidy up UK_data a bit more before merging.

# %%
#We are also going to drop the cols labelled beneficiary 1 and up; and also recipient 1 and up; and 
#funding org postal code, Currency, License
#The reason for dropping these columns is that we won't need this level of detail for what we are trying to do here.

columns_drop = ['Recipient_Org:Location:1:Geographic_Code_Type',
       'Recipient_Org:Location:1:Geographic_Code',
       'Recipient_Org:Location:1:Name',
       'Recipient_Org:Location:2:Geographic_Code_Type',
       'Recipient_Org:Location:2:Geographic_Code',
       'Recipient_Org:Location:2:Name', 'Beneficiary_Location:1:Name', 'Beneficiary_Location:1:Country_Code',
       'Beneficiary_Location:1:Geographic_Code',
       'Beneficiary_Location:1:Geographic_Code_Type',
       'Beneficiary_Location:2:Country_Code',
       'Beneficiary_Location:2:Geographic_Code',
       'Beneficiary_Location:2:Geographic_Code_Type',
       'Beneficiary_Location:3:Country_Code',
       'Beneficiary_Location:3:Geographic_Code',
       'Beneficiary_Location:3:Geographic_Code_Type',
               'Funding_Org:Postal_Code',
                'Retrieved_for_use_in_GrantNav',
               'Currency', 'License_(see_note)' ]

#UK_data.drop(columns_drop, inplace = True, axis = 1)
UK_data.shape
# Out:
# (1139, 56)

# %% [markdown]
# We are now down to 36 columns, down from 56.

# %%
# We need to change col headers and replace: with _ to ensure that any further wrangling is easier
UK_data.columns = UK_data.columns.str.replace(':', '_')

# %%
UK_data.dtypes
# Out:
# Identifier                                        object
# Title                                             object
# Description                                       object
# Currency                                          object
# Amount_Applied_For                               float64
# Amount_Awarded                                   float64
# Amount_Disbursed                                 float64
# Award_Date                                        object
# URL                                               object
# Planned_Dates_Start_Date                          object
# Planned_Dates_End_Date                            object
# Planned_Dates_Duration_(months)                  float64
# Recipient_Org_Identifier                          object
# Recipient_Org_Name                                object
# Recipient_Org_Charity_Number                      object
# Recipient_Org_Company_Number                      object
# Recipient_Org_Postal_Code                         object
# Recipient_Org_Location_0_Geographic_Code_Type     object
# Recipient_Org_Location_0_Geographic_Code          object
# Recipient_Org_Location_0_Name                     object
# Recipient_Org_Location_1_Geographic_Code_Type     object
# Recipient_Org_Location_1_Geographic_Code          object
# Recipient_Org_Location_1_Name                     object
# Recipient_Org_Location_2_Geographic_Code_Type     object
# Recipient_Org_Location_2_Geographic_Code          object
# Recipient_Org_Location_2_Name                     object
# Funding_Org_Identifier                            object
# Funding_Org_Name                                  object
# Funding_Org_Postal_Code                           object
# Grant_Programme_Code                              object
# Grant_Programme_Title                             object
# Grant_Programme_URL                               object
# Beneficiary_Location_0_Name                       object
# Beneficiary_Location_0_Country_Code               object
# Beneficiary_Location_0_Geographic_Code            object
# Beneficiary_Location_0_Geographic_Code_Type       object
# Beneficiary_Location_1_Name                       object
# Beneficiary_Location_1_Country_Code               object
# Beneficiary_Location_1_Geographic_Code            object
# Beneficiary_Location_1_Geographic_Code_Type       object
# Beneficiary_Location_2_Country_Code               object
# Beneficiary_Location_2_Geographic_Code            object
# Beneficiary_Location_2_Geographic_Code_Type       object
# Beneficiary_Location_3_Country_Code               object
# Beneficiary_Location_3_Geographic_Code            object
# Beneficiary_Location_3_Geographic_Code_Type       object
# From_An_Open_Call?                                object
# Data_Source                                       object
# Publisher_Name                                    object
# Recipient_Region                                  object
# Recipient_District                                object
# Recipient_District_Geographic_Code                object
# Recipient_Ward                                    object
# Recipient_Ward_Geographic_Code                    object
# Retrieved_for_use_in_GrantNav                     object
# License_(see_note)                                object
# dtype: object

# %% [markdown]
# #### Adding a Financial Year column and a Country column

# %%
#Define a function setting out the financial year(s) to populate using Award_Date

def financial_year(row):
    if row ['Award_Date'] > '2015-03-31' and row ['Award_Date'] < '2016-04-01':
        val= '2015/16'
    elif row ['Award_Date'] > '2016-03-31' and row ['Award_Date'] < '2017-04-01':
        val= '2016/17'
    elif row ['Award_Date'] > '2017-03-31' and row ['Award_Date'] < '2018-04-01':
        val= '2017/18'
    elif row ['Award_Date'] > '2018-03-31' and row ['Award_Date'] < '2019-04-01':
        val= '2018/19'
    else:
        val = '2019/20'
    return val

# %%
#create new column 'financial year' using the function 
UK_data['Financial_Year'] = UK_data.apply(financial_year, axis=1)

# %%
#Check application of the function
#UK_data [['Award_Date','Financial_Year']]

# %%
UK_data.isnull().sum()
#There are actually very few cols that have no nulls at all.
# Out:
# Identifier                                          0
# Title                                               0
# Description                                         0
# Currency                                            0
# Amount_Applied_For                                778
# Amount_Awarded                                      0
# Amount_Disbursed                                 1113
# Award_Date                                          0
# URL                                               787
# Planned_Dates_Start_Date                          346
# Planned_Dates_End_Date                            348
# Planned_Dates_Duration_(months)                   396
# Recipient_Org_Identifier                            0
# Recipient_Org_Name                                  0
# Recipient_Org_Charity_Number                      218
# Recipient_Org_Company_Number                      739
# Recipient_Org_Postal_Code                         859
# Recipient_Org_Location_0_Geographic_Code_Type     839
# Recipient_Org_Location_0_Geographic_Code          734
# Recipient_Org_Location_0_Name                     665
# Recipient_Org_Location_1_Geographic_Code_Type     932
# Recipient_Org_Location_1_Geographic_Code          764
# Recipient_Org_Location_1_Name                     769
# Recipient_Org_Location_2_Geographic_Code_Type     933
# Recipient_Org_Location_2_Geographic_Code          952
# Recipient_Org_Location_2_Name                     957
# Funding_Org_Identifier                              0
# Funding_Org_Name                                    0
# Funding_Org_Postal_Code                          1115
# Grant_Programme_Code                              422
# Grant_Programme_Title                             236
# Grant_Programme_URL                              1124
# Beneficiary_Location_0_Name                       573
# Beneficiary_Location_0_Country_Code               784
# Beneficiary_Location_0_Geographic_Code            670
# Beneficiary_Location_0_Geographic_Code_Type       678
# Beneficiary_Location_1_Name                      1135
# Beneficiary_Location_1_Country_Code              1134
# Beneficiary_Location_1_Geographic_Code           1130
# Beneficiary_Location_1_Geographic_Code_Type      1130
# Beneficiary_Location_2_Country_Code              1134
# Beneficiary_Location_2_Geographic_Code           1134
# Beneficiary_Location_2_Geographic_Code_Type      1134
# Beneficiary_Location_3_Country_Code              1134
# Beneficiary_Location_3_Geographic_Code           1134
# Beneficiary_Location_3_Geographic_Code_Type      1134
# From_An_Open_Call?                               1080
# Data_Source                                         0
# Publisher_Name                                      0
# Recipient_Region                                  411
# Recipient_District                                416
# Recipient_District_Geographic_Code                416
# Recipient_Ward                                    576
# Recipient_Ward_Geographic_Code                    576
# Retrieved_for_use_in_GrantNav                       0
# License_(see_note)                                  0
# Financial_Year                                      0
# dtype: int64

# %%
# Add Country column
#As the geographic code starts with E, N, S and W respectively, we will simply take the first letter
# and put a copy in a the new column
#Where we have a null in the geographic code column, "n" will populate the new column.
UK_data['Country'] = UK_data['Recipient_District_Geographic_Code'].astype(str).str[0]

# %% [markdown]
# ### Step 2: Prep and understand the data relating to when data from funders started being part of the GrantNav database

# %% [markdown]
# Databases aren't built in a day, so before we delve into analysing the 360 Giving data we need to understand which funders of the funders we are interested started sharing data with 360 Giving when.

# %%
Joiners_360.columns
# Out:
# Index(['Publisher_Name', 'Publisher_prefix', 'First_published_date',
#        'First_grant_award_date', 'Latest_grant_award_date',
#        'GrantNav_Publisher_link'],
#       dtype='object')

# %%
Joiners_360 ['Publisher_Name'].unique().size
# Out:
# 146

# %%
Joiners_360.head(2)
# Out:
#                    Publisher_Name Publisher_prefix First_published_date  \
# 0            A B Charitable Trust        360G-ABCT           21/06/2018
# 1  Andrew Lloyd Webber Foundation        360G-ALWF           06/10/2020
#
#   First_grant_award_date Latest_grant_award_date  \
# 0             22/01/2013              07/07/2020
# 1             01/09/2010              21/04/2020
#
#                                      GrantNav_Publisher_link
# 0  https://grantnav.threesixtygiving.org/publisher/360G-ABCT
# 1  https://grantnav.threesixtygiving.org/publisher/360G-ALWF

# %%
#Joiners_360.info()
#all non null so no problems on joining the two

# %% [raw]
# There are more unique entries in Joiners_360 than there are in UK_data. This is as expected because not all funders will fund bereavement services.

# %% [markdown]
# ### Step 3: Merge the two datasets into one large dataset

# %%
UK_data_merged = pd.merge(UK_data, Joiners_360, on = "Publisher_Name", how = 'left')

# %%
UK_data_merged.shape
# Out:
# (1139, 63)

# %%
#drop a couple of irrelevant cols
cols_drop = ['Publisher_prefix','GrantNav_Publisher_link']
UK_data_merged.drop(cols_drop, inplace = True, axis = 1)

# %%
#We need to rename some columns to be clear the info relates to the publisher and not the specific grant
UK_data_merged_1 = UK_data_merged.rename(columns = {'First_published_date': 'Publisher_first_in_DB', 
                                                  'First_grant_award_date': 'Publisher_first_grant_in_DB',
                                                 'Latest_grant_award_date': 'Publisher_most_recent_in_DB'},
                                                  inplace = False)

# %%
#Change publisher first in DB to date time
UK_data_merged_1["Publisher_first_in_DB"] = pd.to_datetime( UK_data_merged_1["Publisher_first_in_DB"])
UK_data_merged_1["Publisher_first_grant_in_DB"] = pd.to_datetime( UK_data_merged_1["Publisher_first_grant_in_DB"])
UK_data_merged_1["Publisher_most_recent_in_DB"] = pd.to_datetime( UK_data_merged_1["Publisher_most_recent_in_DB"])

# %%
#I need to allocate when publishers put their first grant into the DB into FYs.
#This function is really clunky. Needed to basically restate as not abstracted 
#enough. 
#And I need to remember that I need to apply this on string variables. 
def financial_year1(row):
    if row ['Publisher_first_grant_in_DB'] > '1996-05-11' and row ['Publisher_first_grant_in_DB'] < '2015-04-01':
        val = 'Pre_2014/15'
    elif row ['Publisher_first_grant_in_DB'] > '2015-03-31' and row ['Publisher_first_grant_in_DB'] < '2016-04-01':
        val= '2015/16'
    elif row ['Publisher_first_grant_in_DB'] > '2016-03-31' and row ['Publisher_first_grant_in_DB'] < '2017-04-01':
        val= '2016/17'
    elif row ['Publisher_first_grant_in_DB'] > '2017-03-31' and row ['Publisher_first_grant_in_DB'] < '2018-04-01':
        val= '2017/18'
    elif row ['Publisher_first_grant_in_DB'] > '2018-03-31' and row ['Publisher_first_grant_in_DB'] < '2019-04-01':
        val= '2018/19'
    elif row ['Publisher_first_grant_in_DB'] > '2019-03-31' and row ['Publisher_first_grant_in_DB'] < '2020-04-01':
        val = '2019/20'
    else:
        val = '2020/21'
    return val

# %%
financial_year1
# Out:
# <function __main__.financial_year1(row)>

# %%
#ensure everything is a sting so I can apply the function
UK_data_merged_1 = UK_data_merged_1.astype(str)

# %%
#Create a new col Financial_Year_Publisher_1st_Grant
UK_data_merged_1['Financial_Year_Publisher_1st_Grant'] = UK_data_merged_1.apply(financial_year1, axis=1)

# %%
#Let's compare the two cols and see whether this has worked

UK_data_merged_1[['Publisher_first_grant_in_DB','Financial_Year_Publisher_1st_Grant']].sample(3)
# Out:
#     Publisher_first_grant_in_DB Financial_Year_Publisher_1st_Grant
# R S Macdonald Charitable Trust                                         0
# Scottish Council For Voluntary Organisations                           5
# Seafarers UK                                                           0
# Sir George Martin Trust                                                0
# Somerset Community Foundation                                         35
# Staples Trust                                                          1
# Stockport MBC                                                          0
# Suffolk Community Foundation                                           0
# Sussex Community Foundation                                            0
# The Big Lottery Fund                                                 251
# The Bromley Trust                                                      0
# The Childhood Trust                                                    3
# The Clothworkers Foundation                                            0
# The Dulverton Trust                                                    2
# The Dunhill Medical Trust                                              1
# The Fore                                                               3
# The Funding Network                                                    0
# The Henry Smith Charity                                               10
# The National Lottery Community Fund                                  135
# The National Lottery Heritage Fund                                     2
# The Robertson Trust                                                    0
# The Tudor Trust                                                        8
# The Wellcome Trust                                                    16
# Trafford Housing Trust Social Investment                               1
# True Colours Trust                                                    24
# Trust for London                                                       0
# Tuixen Foundation                                                      5
# Two Ridings Community Foundation                                       0
# Virgin Money Foundation                                                0
# Wates Foundation                                                       0
# Wiltshire Community Foundation                                         0
# Wolfson Foundation                                                     2
# Woodward Charitable Trust                                              3

# %%
#Export to csv
when1.to_csv ('C:/Users/sonja/Desktop/Life_Admin/Bereavement_Services/when_funders_joined.csv')
                  #index = False, header=True)

# %% [markdown]
# Following discussion:
#  - We have agreed to focus on the past 3 financial years.
# Also, agreed to drop:
#  - Ministry of Justice - all the grants are complete outliers with regard to size. also they aren't a non statutory funder, so no clear why they are in GrantNav in the first place.
#  - The 8 orgs for which data doesn't date back for at least three years.
# (EsmÃ©e Fairbairn Foundation
# Community Foundation for Northern Ireland
# Cornwall Community Foundation
# Leeds Community Foundation
# Northamptonshire Community Foundation
# Community Foundation in Wales
# Hertfordshire Community Foundation
# Wates Foundation)

# %% [markdown]
# ### Step 4: Reduce to a 3 Financial Year dataset (following analysis in Step 3)

# %%
UK_data_merged_1.shape
# Out:
# (1139, 62)

# %%
#set financial_year col as the index col
UK_data_merged_1 = UK_data_merged_1.set_index(UK_data_merged_1['Financial_Year'])
UK_data_merged_1 = UK_data_merged_1.sort_index()

# %%
#We want 3 FY;s worth
UK_data_merged_3FY = UK_data_merged_1 ['2017/18': '2019/20']
UK_data_merged_3FY.shape
# Out:
# (866, 62)

# %%
UK_data_merged_3FY.sample(5)
# Out:
#                                 Identifier  \
# Financial_Year
# 2018/19                 360G-CiN-2018-1722
# 2017/18                360G-COOPGROUP-5008
# 2018/19                     360G-phf-33049
# 2019/20         360G-tnlcomfund-0010355146
# 2019/20                    360G-CR-4198079
#
#                                                                                          Title  \
# Financial_Year
# 2018/19                                                    Grant to Listening Ear (Merseyside)
# 2017/18                                                   Grant to Phoenix Bereavement Support
# 2018/19         Open justice in the coronial system: transparency, integrity and accessibility
# 2019/20                                                                      Somewhere To Turn
# 2019/20                                                                  Experts by Experience
#
#                                                                                                                                                                                                                                                               Description  \
# Financial_Year
# 2018/19                                        The Butterflies service will offer group therapy and one to one support to children and young people affected by bereavement, divorce or separation. It will lead to increased emotional wellbeing, happiness and safety.
# 2017/18                                                                                                                                               We want to take local bereaved children to an outdoor centre for a fun day out together, to build their confidence.
# 2018/19         Dr George Julian has participated in inquests into the deaths of learning disabled people whilst in NHS care, and supported the bereaved families as a family representative and advocate in investigation processes. Through this grant, she will inv...
# 2019/20                            The funding will be used to improve volunteering resources to provide support people who are experiencing bereavement. The project aims to aid people in combatting depression, isolation and other negative effects on mental health.
# 2019/20         The project will work in North Tyneside with young adult carers, male young carers and bereaved young carers to identify how improvements can be made in services for these groups. A Research Facilitator will recruit young carers, who will act as ...
#
#                Currency Amount_Applied_For Amount_Awarded Amount_Disbursed  \
# Financial_Year
# 2018/19             GBP                nan       125572.0              nan
# 2017/18             GBP                nan        3819.64              nan
# 2018/19             GBP            14250.0        14650.0          14650.0
# 2019/20             GBP                nan        10000.0              nan
# 2019/20             GBP                nan        49966.0              nan
#
#                 Award_Date  URL Planned_Dates_Start_Date  \
# Financial_Year
# 2018/19         2018-06-27  nan               2019-04-01
# 2017/18         2017-11-29  nan                      nan
# 2018/19         2018-09-06  nan               2018-12-01
# 2019/20         2019-05-03  nan               2019-05-08
# 2019/20         2019-07-03  nan               2019-10-07
#
#                Planned_Dates_End_Date Planned_Dates_Duration_(months)  \
# Financial_Year
# 2018/19                    2022-04-01                            36.0
# 2017/18                           nan                             nan
# 2018/19                    2019-12-31                             7.0
# 2019/20                    2020-05-08                            12.0
# 2019/20                    2021-05-30                            18.0
#
#                Recipient_Org_Identifier  \
# Financial_Year
# 2018/19                  GB-CHC-1073184
# 2017/18                  GB-CHC-1147645
# 2018/19              360G-phf-ORG-19753
# 2019/20                   GB-CHC-208078
# 2019/20                  GB-CHC-1051472
#
#                                             Recipient_Org_Name  \
# Financial_Year
# 2018/19                             Listening Ear (Merseyside)
# 2017/18                            Phoenix Bereavement Support
# 2018/19                                        Georgina Julian
# 2019/20         Cruse Bereavement Care Bexley and Bromley Area
# 2019/20                           North Tyneside Carers Centre
#
#                Recipient_Org_Charity_Number Recipient_Org_Company_Number  \
# Financial_Year
# 2018/19                             1073184                          nan
# 2017/18                             1147645                          nan
# 2018/19                                 nan                          nan
# 2019/20                              208078                       638709
# 2019/20                             1051472                     03130902
#
#                Recipient_Org_Postal_Code  \
# Financial_Year
# 2018/19                              nan
# 2017/18                          HR4 9HP
# 2018/19                              nan
# 2019/20                              nan
# 2019/20                              nan
#
#                Recipient_Org_Location_0_Geographic_Code_Type  \
# Financial_Year
# 2018/19                                                 Ward
# 2017/18                                                  nan
# 2018/19                                                  nan
# 2019/20                                                   WD
# 2019/20                                                 CTRY
#
#                Recipient_Org_Location_0_Geographic_Code  \
# Financial_Year
# 2018/19                                       E05010937
# 2017/18                                             nan
# 2018/19                                             nan
# 2019/20                                             nan
# 2019/20                                       E92000001
#
#                Recipient_Org_Location_0_Name  \
# Financial_Year
# 2018/19                       Halewood South
# 2017/18                                  nan
# 2018/19                                  nan
# 2019/20                               Sidcup
# 2019/20                              England
#
#                Recipient_Org_Location_1_Geographic_Code_Type  \
# Financial_Year
# 2018/19                                                  nan
# 2017/18                                                  nan
# 2018/19                                                  nan
# 2019/20                                                  WPC
# 2019/20                                              RGN/GOR
#
#                Recipient_Org_Location_1_Geographic_Code  \
# Financial_Year
# 2018/19                                             nan
# 2017/18                                             nan
# 2018/19                                             nan
# 2019/20                                       E14000869
# 2019/20                                       E12000001
#
#                Recipient_Org_Location_1_Name  \
# Financial_Year
# 2018/19                                  nan
# 2017/18                                  nan
# 2018/19                                  nan
# 2019/20                Old Bexley and Sidcup
# 2019/20                           North East
#
#                Recipient_Org_Location_2_Geographic_Code_Type  \
# Financial_Year
# 2018/19                                                  nan
# 2017/18                                                  nan
# 2018/19                                                  nan
# 2019/20                                                   LA
# 2019/20                                                  LAD
#
#                Recipient_Org_Location_2_Geographic_Code  \
# Financial_Year
# 2018/19                                             nan
# 2017/18                                             nan
# 2018/19                                             nan
# 2019/20                                       E09000004
# 2019/20                                       E08000022
#
#                Recipient_Org_Location_2_Name Funding_Org_Identifier  \
# Financial_Year
# 2018/19                                  nan          GB-CHC-802052
# 2017/18                                  nan        GB-COH-IP00525R
# 2018/19                                  nan         GB-CHC-1102927
# 2019/20                               Bexley           GB-GOR-PB188
# 2019/20                       North Tyneside          GB-CHC-326568
#
#                                    Funding_Org_Name Funding_Org_Postal_Code  \
# Financial_Year
# 2018/19                        BBC Children in Need                     nan
# 2017/18                          Co-operative Group                     nan
# 2018/19                      Paul Hamlyn Foundation                     nan
# 2019/20         The National Lottery Community Fund                     nan
# 2019/20                                Comic Relief                     nan
#
#                Grant_Programme_Code  \
# Financial_Year
# 2018/19                         nan
# 2017/18                         nan
# 2018/19                         nan
# 2019/20                       AFEX1
# 2019/20                         nan
#
#                                                Grant_Programme_Title  \
# Financial_Year
# 2018/19                                                  Main Grants
# 2017/18                                                          nan
# 2018/19         Nurturing Ideas and People - Ideas and Pioneers Fund
# 2019/20                              National Lottery Awards for All
# 2019/20                              #iwill Youth Social Action Fund
#
#                Grant_Programme_URL Beneficiary_Location_0_Name  \
# Financial_Year
# 2018/19                        nan                         nan
# 2017/18                        nan                         HR4
# 2018/19                        nan                         nan
# 2019/20                        nan                         nan
# 2019/20                        nan              United Kingdom
#
#                Beneficiary_Location_0_Country_Code  \
# Financial_Year
# 2018/19                                        nan
# 2017/18                                        nan
# 2018/19                                         GB
# 2019/20                                        nan
# 2019/20                                         GB
#
#                Beneficiary_Location_0_Geographic_Code  \
# Financial_Year
# 2018/19                                           nan
# 2017/18                                           HR4
# 2018/19                                           nan
# 2019/20                                           nan
# 2019/20                                     K02000001
#
#                Beneficiary_Location_0_Geographic_Code_Type  \
# Financial_Year
# 2018/19                                                nan
# 2017/18                                                 PD
# 2018/19                                                nan
# 2019/20                                                nan
# 2019/20                                               CTRY
#
#                Beneficiary_Location_1_Name  \
# Financial_Year
# 2018/19                                nan
# 2017/18                                nan
# 2018/19                                nan
# 2019/20                                nan
# 2019/20                         North East
#
#                Beneficiary_Location_1_Country_Code  \
# Financial_Year
# 2018/19                                        nan
# 2017/18                                        nan
# 2018/19                                        nan
# 2019/20                                        nan
# 2019/20                                        nan
#
#                Beneficiary_Location_1_Geographic_Code  \
# Financial_Year
# 2018/19                                           nan
# 2017/18                                           nan
# 2018/19                                           nan
# 2019/20                                           nan
# 2019/20                                     E12000001
#
#                Beneficiary_Location_1_Geographic_Code_Type  \
# Financial_Year
# 2018/19                                                nan
# 2017/18                                                nan
# 2018/19                                                nan
# 2019/20                                                nan
# 2019/20                                            RGN/GOR
#
#                Beneficiary_Location_2_Country_Code  \
# Financial_Year
# 2018/19                                        nan
# 2017/18                                        nan
# 2018/19                                        nan
# 2019/20                                        nan
# 2019/20                                        nan
#
#                Beneficiary_Location_2_Geographic_Code  \
# Financial_Year
# 2018/19                                           nan
# 2017/18                                           nan
# 2018/19                                           nan
# 2019/20                                           nan
# 2019/20                                           nan
#
#                Beneficiary_Location_2_Geographic_Code_Type  \
# Financial_Year
# 2018/19                                                nan
# 2017/18                                                nan
# 2018/19                                                nan
# 2019/20                                                nan
# 2019/20                                                nan
#
#                Beneficiary_Location_3_Country_Code  \
# Financial_Year
# 2018/19                                        nan
# 2017/18                                        nan
# 2018/19                                        nan
# 2019/20                                        nan
# 2019/20                                        nan
#
#                Beneficiary_Location_3_Geographic_Code  \
# Financial_Year
# 2018/19                                           nan
# 2017/18                                           nan
# 2018/19                                           nan
# 2019/20                                           nan
# 2019/20                                           nan
#
#                Beneficiary_Location_3_Geographic_Code_Type From_An_Open_Call?  \
# Financial_Year
# 2018/19                                                nan                nan
# 2017/18                                                nan                nan
# 2018/19                                                nan                Yes
# 2019/20                                                nan                nan
# 2019/20                                                nan                nan
#
#                                                                                                                              Data_Source  \
# Financial_Year
# 2018/19                              https://www.bbcchildreninneed.co.uk/wp-content/uploads/2020/06/360-giving-data-Master-Upload-3.xlsx
# 2017/18                                                                           https://www.coop.co.uk/downloads/causes-data-2019.xlsx
# 2018/19         https://www.phf.org.uk/wp-content/uploads/2019/07/Paul-Hamlyn-Foundation-360-giving-October-2016-to-March-2019-xlsx.xlsx
# 2019/20                                                            https://www.tnlcommunityfund.org.uk/media/data/grants/2019_20_v4.xlsx
# 2019/20                           https://docs.google.com/spreadsheets/d/1hNGEWC4sA28lx_vr1Ayw72z7fT80349TLvMpCDMRJoc/export?format=xlsx
#
#                                      Publisher_Name Recipient_Region  \
# Financial_Year
# 2018/19                        BBC Children in Need       North West
# 2017/18                          Co-operative Group    West Midlands
# 2018/19                      Paul Hamlyn Foundation              nan
# 2019/20         The National Lottery Community Fund           London
# 2019/20                                Comic Relief       North East
#
#                      Recipient_District Recipient_District_Geographic_Code  \
# Financial_Year
# 2018/19               Knowsley District                          E08000011
# 2017/18         County of Herefordshire                          E06000019
# 2018/19                             nan                                nan
# 2019/20              Bexley London Boro                          E09000004
# 2019/20         North Tyneside District                          E08000022
#
#                      Recipient_Ward Recipient_Ward_Geographic_Code  \
# Financial_Year
# 2018/19         Halewood South Ward                      E05010937
# 2017/18                Central Ward                      E05009449
# 2018/19                         nan                            nan
# 2019/20                         nan                            nan
# 2019/20                         nan                            nan
#
#                Retrieved_for_use_in_GrantNav  \
# Financial_Year
# 2018/19            2020-08-18T03:00:03+02:00
# 2017/18            2020-08-18T03:01:36+02:00
# 2018/19            2020-08-18T03:03:01+02:00
# 2019/20            2020-08-18T03:17:30+02:00
# 2019/20            2020-08-18T03:00:03+02:00
#
#                                                                        License_(see_note)  \
# Financial_Year
# 2018/19                                      https://creativecommons.org/licenses/by/4.0/
# 2017/18                                   https://creativecommons.org/licenses/by-sa/4.0/
# 2018/19                                      https://creativecommons.org/licenses/by/4.0/
# 2019/20         http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/
# 2019/20                                      https://creativecommons.org/licenses/by/4.0/
#
#                Financial_Year Country Publisher_first_in_DB  \
# Financial_Year
# 2018/19               2018/19       E            2016-07-15
# 2017/18               2017/18       E            2017-10-03
# 2018/19               2018/19       n            2016-02-18
# 2019/20               2019/20       E            2016-04-22
# 2019/20               2019/20       E            2016-08-16
#
#                Publisher_first_grant_in_DB Publisher_most_recent_in_DB  \
# Financial_Year
# 2018/19                         2015-01-03                  2020-06-17
# 2017/18                         2017-04-08                  2019-11-15
# 2018/19                         2006-04-20                  2020-04-28
# 2019/20                         2004-01-04                  2020-05-29
# 2019/20                         2015-09-01                  2020-06-23
#
#                Financial_Year_Publisher_1st_Grant
# Financial_Year
# 2018/19                               Pre_2014/15
# 2017/18                                   2017/18
# 2018/19                               Pre_2014/15
# 2019/20                               Pre_2014/15
# 2019/20                                   2015/16

# %%
#let's just cross check this
#UK_data_merged_2FY = UK_data_merged_1 ['2015/16': '2016/17']
#UK_data_merged_2FY.shape
#yup adds up

# %%
 #Export UK_data_merged_3FY
UK_data_merged_3FY.to_csv ('C:/Users/sonja/Desktop/Life_Admin/Bereavement_Services/UK_data_merged_3FY.csv')

# %%
### Reduce the 22 rows relating to the funding orgs for which the time series isn't consistent
##for the 3 FY
#I ended up doing this manually and reading the csv back in.

UK_data_merged_3FY_edited = pd.read_csv('C:/Users/sonja/Desktop/Life_Admin/Bereavement_Services/UK_data_merged_3FY_edited.csv')
UK_data_merged_3FY_edited.shape

#Note: I double checked they both go to AQ in the csv. So the earlier version (@ 63 cols must have
#had empty cols. Sth to pay more attention to next time)
# Out:
# (844, 46)

# %% [markdown]
# ### How much is spent on Bereavement Services?

# %%
amount_fy = UK_data_merged_3FY_edited.groupby(['Financial_Year'])[['Amount_Awarded']].sum()

# %%
amount_fy
# Out:
#                 Amount_Awarded
# Financial_Year
# 2017/18             9624963.93
# 2018/19             8753298.12
# 2019/20             9647862.00

# %%
pd.crosstab(UK_data_merged_3FY_edited.Financial_Year, UK_data_merged_3FY_edited.Amount_Awarded, margins=True, margins_name="Total")
# Out:
# Amount_Awarded  100.0  131.0  150.0  200.0  250.0  300.0  320.0  353.0  360.0  \
# Financial_Year
# 2017/18             2      1      0      1      1      2      2      0      0
# 2018/19             2      0      1      3      5      1      0      1      0
# 2019/20             0      0      0      0      0      0      0      0      1
# Total               4      1      1      4      6      3      2      1      1
#
# Amount_Awarded  462.0  500.0  528.77  553.0  600.0  660.0  700.0  713.0  \
# Financial_Year
# 2017/18             0      4       1      0      1      1      0      0
# 2018/19             0      3       0      0      1      0      0      0
# 2019/20             1      4       0      1      0      0      1      1
# Total               1     11       1      1      2      1      1      1
#
# Amount_Awarded  750.0  800.0  835.33  900.0  924.0  980.0  983.66  990.0  \
# Financial_Year
# 2017/18             1      1       1      1      1      0       1      0
# 2018/19             2      0       0      1      0      0       0      0
(UK_data_merged_3FY_edited ["Funding_Org_Name"] == "Ministry of Justice").sum()
#yes, all good.
# Out:
# 0

# %%
(UK_data_merged_3FY_edited["Funding_Org_Name"] == "Community Foundation for Northern Ireland").sum()
# Out:
# 0

# %%
(UK_data_merged_3FY_edited["Funding_Org_Name"] == "Esmée Fairbairn Foundation").sum()
# Out:
# 0

# %% [markdown]
# ### Step 6: Descriptive stats on the entire dataset and split by Financial Year (n = 844)

# %%
#Ensure relevant cols are floats 
UK_data_merged_3FY_edited ['Planned_Dates_Duration_(months)'] = UK_data_merged_3FY_edited ['Planned_Dates_Duration_(months)'].astype(float)

# %%
UK_data_merged_3FY_edited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 46 columns):
# Unnamed: 0                                       844 non-null int64
# Unnamed: 0.1                                     844 non-null int64
# Financial_Year                                   844 non-null object
# Identifier                                       844 non-null object
# Title                                            844 non-null object
# Description                                      844 non-null object
# Amount_Applied_For                               258 non-null float64
# Amount_Awarded                                   844 non-null float64
# Amount_Disbursed                                 13 non-null float64
# Award_Date                                       844 non-null object
# URL                                              260 non-null object
# Planned_Dates_Start_Date                         561 non-null object
# Planned_Dates_End_Date                           561 non-null object
# Planned_Dates_Duration_(months)                  534 non-null float64
# Recipient_Org_Identifier                         844 non-null object
# Recipient_Org_Name                               844 non-null object
# Recipient_Org_Charity_Number                     702 non-null object
# Recipient_Org_Company_Number                     280 non-null object
# Recipient_Org_Postal_Code                        231 non-null object
# Recipient_Org_Location_0_Geographic_Code_Type    279 non-null object
# Recipient_Org_Location_0_Geographic_Code         274 non-null object
# Recipient_Org_Location_0_Name                    339 non-null object
# Funding_Org_Identifier                           844 non-null object
# Funding_Org_Name                                 844 non-null object
# Grant_Programme_Code                             502 non-null object
# Grant_Programme_Title                            648 non-null object
# Grant_Programme_URL                              10 non-null object
# Beneficiary_Location_0_Name                      437 non-null object
# Beneficiary_Location_0_Country_Code              253 non-null object
# Beneficiary_Location_0_Geographic_Code           368 non-null object
# Beneficiary_Location_0_Geographic_Code_Type      368 non-null object
# From_An_Open_Call?                               21 non-null object
# Data_Source                                      844 non-null object
# Publisher_Name                                   844 non-null object
# Recipient_Region                                 556 non-null object
# Recipient_District                               552 non-null object
# Recipient_District_Geographic_Code               552 non-null object
# Recipient_Ward                                   433 non-null object
# Recipient_Ward_Geographic_Code                   433 non-null object
# Financial_Year.1                                 844 non-null object
# Country                                          844 non-null object
# Publisher_first_in_DB                            844 non-null object
# Publisher_first_grant_in_DB                      844 non-null object
# Publisher_most_recent_in_DB                      844 non-null object
# Financial_Year_Publisher_1st_Grant               844 non-null object
# Tier                                             844 non-null object
# dtypes: float64(4), int64(2), object(40)
# memory usage: 303.4+ KB

# %%
UK_data_merged_3FY_edited.describe()
#Amount applied for and Amount disbured data not being used here. V. high number of nulls and no 
#specific questions of interest.
# Out:
#        Unnamed: 0  Amount_Applied_For  Amount_Awarded  Amount_Disbursed  \
# count  844.000000          258.000000      844.000000         13.000000
# mean   421.500000         9987.353876    33206.308116      13662.820769
# std    243.786108        25333.752921    74285.074028      14599.797545
# min      0.000000            0.000000      100.000000          0.000000
# 25%    210.750000         1000.000000     2923.407500       1500.000000
# 50%    421.500000         3224.310000     8400.000000      10320.000000
# 75%    632.250000         8000.000000    15000.000000      20000.000000
# max    843.000000       180000.000000   566160.000000      40000.000000
#
#        Planned_Dates_Duration_(months)
# count                       534.000000
# mean                         18.116105
# std                          13.067066
# min                           0.000000
# 25%                          11.000000
# 50%                          12.000000
# 75%                          35.000000
# max                          60.000000

# %% [markdown]
# ### Distribution of Amount Awarded (3 year period)

# %%
hist_3_FY = UK_data_merged_3FY_edited ['Amount_Awarded'].hist(bins=50)
plt.title("Distribution of Amounts Awarded (3 Financial Years)")
plt.xlabel("£")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
#amount awarded - distribution

plt.figure(figsize=(7,7))
sn.boxplot(
    data=UK_data_merged_3FY_edited,
        y='Amount_Awarded',
    color='blue')

# %% [markdown]
# ### Planned Duration (months)

# %%
hist_duration = UK_data_merged_3FY_edited ['Planned_Dates_Duration_(months)'].hist(bins=50)
plt.title("Distribution of Planned Grant Duration")
plt.xlabel("months")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plt.figure(figsize=(7,7))
sn.boxplot(
    data=UK_data_merged_3FY_edited,
        y='Planned_Dates_Duration_(months)',
    color='blue')

# %%
Over_60K = UK_data_merged_3FY_edited.loc[UK_data_merged_3FY_edited['Amount_Awarded'] > 60000]

# %%
Over_60K.shape
# Out:
# (125, 45)

# %%
under_15K = UK_data_merged_3FY_edited.loc[UK_data_merged_3FY_edited['Amount_Awarded']  <15000]
under_15K.shape
# Out:
# (632, 45)

# %% [markdown]
# ### Amounts Awarded by Financial Year (n= 844)

# %% [markdown]
# Replotting the box plot to look at the distributions of amounts awarded by financial year. Recall that a box plot helps show comparisons between variables or across levels of a categorical variable - in this case financial year. The main body of the box plot showing the quartiles (25th and 75th percentile). The medians have horizontal lines at the median of each box and while whiskers have the vertical lines extending to the most extreme, non-outlier data points and caps are the horizontal lines at the ends of the whiskers.
# Outliers are defined as points that lie 1.5 times the interquartile range past the quartlies.

# %%
plt.figure(figsize=(7,7))
sn.boxplot(
    data=UK_data_merged_3FY_edited,
    x='Financial_Year',
    y='Amount_Awarded',
    color='blue')

# %%
#Let's look at descriptive stats for the grouped data
UK_data_merged_3FY_edited['Amount_Awarded'].groupby(UK_data_merged_3FY_edited['Financial_Year']).describe()
# Out:
#                 count          mean           std    min       25%     50%  \
# Financial_Year
# 2017/18         310.0  31048.270742  73130.851365  100.0  2029.665  5000.0
# 2018/19         262.0  33409.534809  68269.200772  100.0  3500.000  9345.0
# 2019/20         272.0  35470.080882  81045.908836  360.0  4268.945  9079.5
#
#                     75%       max
# Financial_Year
# 2017/18         15000.0  566160.0
# 2018/19         18000.0  415002.0
# 2019/20         12053.0  500000.0

# %%
#Let's bring Funder in?
sn.set(style="ticks")

g = sn.catplot(x="Financial_Year", y="Amount_Awarded", data=UK_data_merged_3FY_edited)

# %%
UK_data_merged_3FY_edited.to_csv ('C:/Users/sonja/Desktop/Life_Admin/Bereavement_Services/UK_data_merged_3FY_edited.csv') 
                  #index = False, header=True)
